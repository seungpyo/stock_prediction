# %%
import os
train_record_filename = "20231015-181025.json"
train_record_path = os.path.join("..", "logs", train_record_filename)
from record import TrainRecord
from dqn_v1 import DQNTrainConfig
record = TrainRecord.load(train_record_path)

record.plot()
record.metadata
# Out:
# {'train_episodes': 250,
#  'batches_per_episode': 20,
#  'batch_size': 128,
#  'ticker': 'SPY',
#  'start_date': '2010-01-01',
#  'end_date': '2014-12-31',
#  'initial_cash': 10000.0}
